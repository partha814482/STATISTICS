# %% [markdown]
# Lifestyle Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the data set
data =pd.read_csv(r"C:\Users\HP\Downloads\Sleep_health_and_lifestyle_dataset.csv")
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
data.shape
# Out:
# (374, 13)

# %%
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
data.tail()
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 369                       75             3   Overweight         140/95
# 370                       75             3   Overweight         140/95
# 371                       75             3   Overweight         140/95
# 372                       75             3   Overweight         140/95
# 373                       75             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 369          68         7000    Sleep Apnea
# ...

# %%
data.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
#data.rpow

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Person ID'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Sleep Duration'}>],
#        [<Axes: title={'center': 'Quality of Sleep'}>,
#         <Axes: title={'center': 'Physical Activity Level'}>,
#         <Axes: title={'center': 'Stress Level'}>],
#        [<Axes: title={'center': 'Heart Rate'}>,
#         <Axes: title={'center': 'Daily Steps'}>, <Axes: >]], dtype=object)

# %%
data.isnull()
# Out:
#      Person ID  Gender    Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0        False   False  False       False           False             False
# 1        False   False  False       False           False             False
# 2        False   False  False       False           False             False
# 3        False   False  False       False           False             False
# 4        False   False  False       False           False             False
# ..         ...     ...    ...         ...             ...               ...
# 369      False   False  False       False           False             False
# 370      False   False  False       False           False             False
# 371      False   False  False       False           False             False
# 372      False   False  False       False           False             False
# 373      False   False  False       False           False             False
#
# ...

# %%
data.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
data.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
data['Person ID']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 369    370
# 370    371
# 371    372
# 372    373
# 373    374
# Name: Person ID, Length: 374, dtype: int64

# %%
data['Age']
# Out:
# 0      27
# 1      28
# 2      28
# 3      28
# 4      28
#        ..
# 369    59
# 370    59
# 371    59
# 372    59
# 373    59
# Name: Age, Length: 374, dtype: int64

# %%
data['Sleep Duration']
# Out:
# 0      6.1
# 1      6.2
# 2      6.2
# 3      5.9
# 4      5.9
#       ...
# 369    8.1
# 370    8.0
# 371    8.1
# 372    8.1
# 373    8.1
# Name: Sleep Duration, Length: 374, dtype: float64

# %%
data['Heart Rate']
# Out:
# 0      77
# 1      75
# 2      75
# 3      85
# 4      85
#        ..
# 369    68
# 370    68
# 371    68
# 372    68
# 373    68
# Name: Heart Rate, Length: 374, dtype: int64

# %%
data['Blood Pressure']
# Out:
# 0      126/83
# 1      125/80
# 2      125/80
# 3      140/90
# 4      140/90
#         ...
# 369    140/95
# 370    140/95
# 371    140/95
# 372    140/95
# 373    140/95
# Name: Blood Pressure, Length: 374, dtype: object

# %%
data.BMI Category
# Out:
#   Cell In[55], line 1
#     data.BMI Category
#              ^
# SyntaxError: invalid syntax

# %%
data['BMI Category']
# Out:
# 0      Overweight
# 1          Normal
# 2          Normal
# 3           Obese
# 4           Obese
#           ...
# 369    Overweight
# 370    Overweight
# 371    Overweight
# 372    Overweight
# 373    Overweight
# Name: BMI Category, Length: 374, dtype: object

# %%
data.Age
# Out:
# 0      27
# 1      28
# 2      28
# 3      28
# 4      28
#        ..
# 369    59
# 370    59
# 371    59
# 372    59
# 373    59
# Name: Age, Length: 374, dtype: int64

# %%
data.Sleep Disorder
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13420\69308373.py in ?()
# ----> 1 data.SleepDisorder
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'SleepDisorder'

# %% [markdown]
# data.Age works because Age is a valid Python identifier:
#
# No spaces
#
# No special characters
#
# Doesn’t clash with Pandas methods
#
# So Pandas allows dot notation in this case.
#
# But data.Sleep Disorder fails because Sleep Disorder has a space, which makes it invalid in dot notation.

# %%
data['Sleep Disorder']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3      Sleep Apnea
# 4      Sleep Apnea
#           ...
# 369    Sleep Apnea
# 370    Sleep Apnea
# 371    Sleep Apnea
# 372    Sleep Apnea
# 373    Sleep Apnea
# Name: Sleep Disorder, Length: 374, dtype: object

# %%
data.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
vis1 = sns.distplot(data['Age'])

# %%
vis2 = sns.distplot(data['Daily Steps'])

# %%
vis3 = sns.displot(data['Sleep Duration'],bins = 5)

# %%
vis3 = sns.distplot(data['Sleep Duration'],bins = 5)

# %%
vis4 = sns.distplot(data['Stress Level'])

# %%
vis5 = sns.distplot(data['Quality of Sleep'])

# %%
vis5 = sns.distplot(data['Sleep Duration'])

# %%
sns.scatterplot(data=data,x = 'Occupation', y = 'BMI Category')
# Out:
# <Axes: xlabel='Occupation', ylabel='BMI Category'>

# %%
j = sns.jointplot(data=data,x = 'Age', y = 'Sleep Duration')

# %%
j1 = sns.jointplot(data=data,x = 'Age', y = 'Physical Activity Level')

# %%
j1 = sns.jointplot(data=data,x = 'Age', y = 'Physical Activity Level',kind = 'scatter')

# %%
j1 = sns.jointplot(data=data,x = 'Age', y = 'Physical Activity Level', kind = 'reg')

# %%
j2 = sns.jointplot(data=data, x = 'Quality of Sleep', y = 'Heart Rate')

# %%
j2 = sns.jointplot(data=data, x = 'Quality of Sleep', y = 'Heart Rate', kind = 'resid')

# %%
j2 = sns.jointplot(data=data, x = 'Quality of Sleep', y = 'Heart Rate',kind = 'reg')

# %%
j2 = sns.jointplot(data=data, x = 'Heart Rate', y = 'Daily Steps',kind = 'reg')

# %%
j2 = sns.jointplot(data=data, x = 'Heart Rate', y = 'Daily Steps',kind = 'hex')

# %%
j2 = sns.jointplot(data=data, x = 'Quality of Sleep', y = 'Heart Rate',kind = 'hex')

# %%
j2 = sns.jointplot(data=data, x = 'Quality of Sleep', y = 'Heart Rate',kind = 'hist')

# %%
j1 = sns.jointplot(data=data,x = 'Age', y = 'Physical Activity Level',kind ='hex')

# %%
j1 = sns.jointplot(data=data,x = 'Age', y = 'Physical Activity Level',kind ='hist')

# %%
j1 = sns.jointplot(data=data,x = 'Age', y = 'Physical Activity Level',kind = 'resid')

# %%
data['Age']
# Out:
# 0      27
# 1      28
# 2      28
# 3      28
# 4      28
#        ..
# 369    59
# 370    59
# 371    59
# 372    59
# 373    59
# Name: Age, Length: 374, dtype: int64

# %%
sns.set_style('darkgrid') # Here set_style is used to change the background colour of the graph

# %%
m = sns.distplot(data['Age'])

# %%
m = sns.distplot(data['Age'],bins = 12)

# %%
sns.set_style('dark')
m2 = plt.hist(data['Stress Level'])
# styles = ["white", "dark", "whitegrid", "darkgrid", "ticks"]

# %%
m3 = plt.hist(data['Physical Activity Level'],bins=9)

# %%
sns.barplot(data=data, x = 'Age', y = 'Physical Activity Level')
# Out:
# <Axes: xlabel='Age', ylabel='Physical Activity Level'>

# %%
plt.hexbin(data['Age'], data['Daily Steps'], gridsize=30, cmap='Blues')
plt.colorbar(label="Count in bin")
plt.xlabel("Age")
plt.ylabel("Daily Steps")
plt.title("Hexbin plot of Age vs Daily Steps")
plt.show()

# %%
plt.hist(data['Daily Steps'], bins=30, color='skyblue')
plt.xlabel("Daily Steps")
plt.ylabel("Frequency")
plt.title("Distribution of Daily Steps")
plt.show()

# %%
plt.hist(data[data['Gender'] == 'Male']['Sleep Duration'],bins=10,label='Male')
plt.hist(data[data['Gender'] == 'Female']['Sleep Duration'],bins=10,label='Female')
# Out:
# (array([16., 21., 32.,  7., 15., 23.,  1.,  1., 37., 32.]),
#  array([5.8 , 6.07, 6.34, 6.61, 6.88, 7.15, 7.42, 7.69, 7.96, 8.23, 8.5 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data[data['Gender'] == 'Male']['Sleep Duration'],bins=10,label='Male')
plt.hist(data[data['Gender'] == 'Female']['Sleep Duration'],bins=10,label='Female')
plt.legend()
plt.xlabel('sleep ')
plt.xlabel('sleep Duration (hours)')
plt.ylabel('Frequency')
plt.title('sleep duration by gender')
# Out:
# Text(0.5, 1.0, 'sleep duration by gender')

# %%
plt.hist(data[data['Gender'] == 'Male']['Daily Steps'],bins=10,label='Male')
plt.hist(data[data['Gender'] == 'Female']['Daily Steps'],bins=10,label='Female')
plt.legend()
plt.xlabel('Dally Steps')
plt.ylabel('No of people')
plt.title("Distribution of Daily Steps by Gender")
# Out:
# Text(0.5, 1.0, 'Distribution of Daily Steps by Gender')

# %%
plt.hist(data[data['Gender'] == 'Male']['Heart Rate'],bins=10,label='Male')
plt.hist(data[data['Gender'] == 'Female']['Heart Rate'],bins=10,label='Female')
plt.legend()
plt.xlabel('Heart rate of people')
plt.ylabel('no of people')
plt.title('Distribution of heart rate by gender')
# Out:
# Text(0.5, 1.0, 'Distribution of heart rate by gender')

# %%
plt.hist(data[data['Gender'] == 'Male']['Stress Level'],bins = 10, label='Male')
plt.hist(data[data['Gender'] == 'Female']['Stress Level'],bins = 10, label='Feale')
plt.xlabel('Stress Level')
plt.ylabel('No of people')
plt.legend()
plt.title('Distribution of Stress levele by Gender')
# Out:
# Text(0.5, 1.0, 'Distribution of Stress levele by Gender')

# %%
plt.hist(data[data['Gender'] == 'Male']['Blood Pressure'],bins = 9, label='Male')
plt.hist(data[data['Gender'] == 'Female']['Blood Pressure'],bins = 9, label='Feale')
values = [4, 69, 5, 0, 31, 45, 33, 0] 
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()  
plt.xlabel('Blood Presser')
plt.ylabel('No of pepole')
plt.title('Distribution of Blood presser by Gender')
# Out:
# Text(0.5, 1.0, 'Distribution of Blood presser by Gender')

# %%
plt.hist(data[data['Gender'] == 'Male']['Occupation'],bins = 9, label='Male')
plt.hist(data[data['Gender'] == 'Female']['Occupation'],bins = 9, label='Feale')
values = [4, 69, 5, 0, 31, 45, 33, 0] 
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()  
plt.xlabel('Occopation of people')
plt.ylabel('No of people')
plt.title('Distribution of occopation by grnder')
# Out:
# Text(0.5, 1.0, 'Distribution of occopation by grnder')

# %%
# Count values by gender and disorder
male_counts = data[data['Gender'] == 'Male']['Sleep Disorder'].value_counts()
female_counts = data[data['Gender'] == 'Female']['Sleep Disorder'].value_counts()

# Align categories
categories = sorted(set(data['Sleep Disorder'].dropna()))
x = range(len(categories))

plt.bar([i - 0.2 for i in x], [male_counts.get(cat, 0) for cat in categories],
        width=0.4, label='Male')
plt.bar([i + 0.2 for i in x], [female_counts.get(cat, 0) for cat in categories],
        width=0.4, label='Female')

plt.xticks(x, categories, rotation=45, ha='right')
plt.xlabel('Sleep Disorder')
plt.ylabel('No. of People')
plt.title('Distribution of Sleep Disorder by Gender')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##['Sleep Disorder'].value_counts() → counts how many males fall into each sleep disorder category.
# ##set(...).dropna() → gets unique sleep disorder types (ignores missing values).
#
# ##sorted(...) → sorts them alphabetically for consistent x-axis order.
#
# ##x = range(len(categories)) → assigns numeric positions (0,1,2,...) for each category.
# ##[i - 0.2 for i in x] → shifts male bars slightly left.
#
# ##[i + 0.2 for i in x] → shifts female bars slightly right.
#
# ##width=0.4 → each bar takes 40% width → creates space between them.
#
# ##get(cat, 0) → ensures if a category is missing (e.g., no female with "Sleep Apnea"), it returns 0 instead of error.

# %%
plt.hist(data[data['Gender'] == 'Male']['BMI Category'],bins = 9, label='Male')
plt.hist(data[data['Gender'] == 'Female']['BMI Category'],bins = 9, label='Feale')
values = [4, 69, 5, 0, 31, 45, 33, 0] 
plt.xticks(rotation=45, ha='right')  
plt.tight_layout() 
plt.xlabel('BMI Category')
plt.ylabel('No of people')
plt.title('Distribution of BMI Category by gender')
# Out:
# Text(0.5, 1.0, 'Distribution of BMI Category by gender')

# %%
plt.hist(data[data['Gender'] == 'Male']['Age'],bins = 9, label='Male')
plt.hist(data[data['Gender'] == 'Female']['Age'],bins = 9, label='Feale')
values = [4, 69, 5, 0, 31, 45, 33, 0] 
plt.xticks(rotation=45, ha='right')  
plt.tight_layout() 
plt.xlabel('Age')
plt.ylabel('No of people')
plt.title('Distribution of Age by gender')
# Out:
# Text(0.5, 1.0, 'Distribution of Age by gender')

# %%
plt.hist(data[data['Gender'] == 'Male']['Age'],bins = 9, label='Male')
plt.hist(data[data['Gender'] == 'Female']['Age'],bins = 9, label='Feale')
plt.hist(data[data['Gender'] == 'Male']['Occupation'],bins = 9, label='Male')
plt.hist(data[data['Gender'] == 'Female']['Occupation'],bins = 9, label='Feale')
values = [4, 69, 5, 0, 31, 45, 33, 0] 
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()

# %%
for occupation in data['Occupation'].cat.categories:
    print(occupation)
# Out:
# Accountant
# Doctor
# Engineer
# Lawyer
# Manager
# Nurse
# Sales Representative
# Salesperson
# Scientist
# Software Engineer
# Teacher

# %%
# Ensure the column is categorical
data['BMI Category'] = data['BMI Category'].astype('category')

# Loop through each category and print
for BMI_Category in data['BMI Category'].cat.categories:
    print(BMI_Category)
# Out:
# Normal
# Normal Weight
# Obese
# Overweight

# %%
# Ensure the column is categorical
data['Sleep Disorder'] = data['Sleep Disorder'].astype('category')

# Loop through each category and print
for Sleep_Disorder in data['Sleep Disorder'].cat.categories:
    print(Sleep_Disorder)
# Out:
# Insomnia
# Sleep Apnea

# %% [markdown]
# LMPLOT

# %%
vis1 = sns.lmplot(data=data, x = 'Sleep Duration', y ='Age',fit_reg=False )

# %%
vis1 = sns.lmplot(data=data, x = 'Sleep Duration', y ='Age',fit_reg=True)

# %%
vis1 = sns.lmplot(data=data, x = 'Age', y ='Sleep Duration',fit_reg=False,hue ='Occupation'  )

# %%
vis1 = sns.lmplot(data=data, x = 'Age', y ='Physical Activity Level',fit_reg=False,hue ='Occupation')

# %%
vis1 = sns.lmplot(data=data, x = 'Stress Level', y ='Heart Rate',fit_reg=False,hue ='Occupation')

# %%
vis1 = sns.lmplot(data=data, x = 'Heart Rate', y ='Daily Steps',fit_reg=False,hue ='Occupation')

# %%
vis2 = sns.lmplot(data=data, x = 'Age', y = 'Physical Activity Level',fit_reg=False,hue = 'BMI Category',height= 10,aspect=1)

# %%
vis1 = sns.lmplot(data=data, x ='Age', y ='Physical Activity Level',fit_reg=False,hue ='Occupation')

# %%
vis1 = sns.lmplot(data=data, x ='Age', y ='Physical Activity Level',fit_reg=False,hue ='BMI Category')

# %% [markdown]
# KDE PLOT

# %%
k1 = sns.kdeplot(data.Age)

# %%
#m2 = sns.kdeplot(data['Gender'])
# we can not use string data in kde plot
# only we use numerical data for single kde plot isualizatiom

# %%
#k2 = sns.kdeplot(data.Sleep Duration)
# in KDE plot if in column name has no space we write like k1 = sns.kdeplot(data.Age)
# if there some space in column name then we write like  k2 = sns.kdeplot(data['Sleep Duration'])

# %%
k2 = sns.kdeplot(data['Sleep Duration'])

# %%
k3 = sns.kdeplot(data['Quality of Sleep'])

# %%
k4 = sns.kdeplot(data['Daily Steps'])

# %%
sns.kdeplot(x='Sleep Duration', data=data, hue='Gender', fill=True)
plt.title("Sleep Duration Distribution by Gender")
plt.show()

# %%
sns.kdeplot(data=data, x = 'Quality of Sleep',hue='Gender',fill=True)
plt.title('Quality of Sleep by Gender')
# Out:
# Text(0.5, 1.0, 'Quality of Sleep by Gender')

# %%
sns.kdeplot(data=data, x = 'Physical Activity Level',hue='Gender',fill=True)
plt.title('Physical Activity Level by Gender')
# Out:
# Text(0.5, 1.0, 'Physical Activity Level by Gender')

# %%
sns.kdeplot(data=data, x = 'Stress Level',hue='Gender',fill=True)
plt.title('Stress Level by Gender')
# Out:
# Text(0.5, 1.0, 'Stress Level by Gender')

# %%
sns.kdeplot(data=data, x = 'Quality of Sleep',hue='Sleep Disorder',fill=True)
plt.title('Quality Sleep by people with Sleep Disorder')
# Out:
# Text(0.5, 1.0, 'Quality Sleep by people with Sleep Disorder')

# %%
sns.kdeplot(data=data, x = 'Stress Level',hue='Occupation',fill=True)
plt.title('Stress levele of people with occopation')
# Out:
# Text(0.5, 1.0, 'Stress levele of people with occopation')

# %%
sns.kdeplot(data=data, x = 'Daily Steps',hue='Occupation',fill=True)
plt.title('Daily Steps of people with occopation')
# Out:
# Text(0.5, 1.0, 'Daily Steps of people with occopation')

# %%
sns.kdeplot(data=data, x = 'Physical Activity Level',hue='Occupation',fill=True)
plt.title('Physical Activity Level of people with occopation')
# Out:
# Text(0.5, 1.0, 'Physical Activity Level of people with occopation')

# %%
k7 = sns.kdeplot(data=data,x = 'Sleep Duration',y ='Quality of Sleep')

# %%
k7 = sns.kdeplot(data=data,x = 'Sleep Duration',y ='Quality of Sleep',shade = True,shade_lowest = False,cmap = 'Reds')

# %%
k7 = sns.kdeplot(data=data,x = 'Sleep Duration',y ='Quality of Sleep',shade = True,shade_lowest = False,cmap = 'Greens')

# %% [markdown]
# for cmap; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Grays', 'Grays_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'berlin', 'berlin_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_grey', 'gist_grey_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gist_yerg', 'gist_yerg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'grey', 'grey_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'managua', 'managua_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'vanimo', 'vanimo_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %%
sns.kdeplot(data=data,x = 'Age', y = 'Physical Activity Level',hade = True,shade_lowest = False,cmap = 'Reds' )
# Out:
# <Axes: xlabel='Age', ylabel='Physical Activity Level'>

# %%
#sns.kdeplot(data=data,x = 'Gender', y = 'Physical Activity Level',hade = True,shade_lowest = False,cmap = 'Reds' )

# %%
sns.countplot(x='Gender', data=data)
plt.title("Distribution of Gender")
plt.show()

# %%
sns.kdeplot(data=data, x='Heart Rate', y='Physical Activity Level', fill=True, cmap='Reds')
# Out:
# <Axes: xlabel='Heart Rate', ylabel='Physical Activity Level'>

# %%
sns.kdeplot(data=data, x='Heart Rate', y='Daily Steps', fill=True, cmap='Reds')
# Out:
# <Axes: xlabel='Heart Rate', ylabel='Daily Steps'>

# %%
sns.kdeplot(data=data, x='Heart Rate', y='Stress Level', fill=True, cmap='Reds')
# Out:
# <Axes: xlabel='Heart Rate', ylabel='Stress Level'>

# %% [markdown]
# SUBPLOT IN MATPLOTLIB

# %%
ax = plt.subplots(1,2,figsize = (12,6))

# %%
ax = plt.subplots(1,5,figsize = (12,6))

# %%
ax = plt.subplots(2,9,figsize = (12,6))

# %% [markdown]
# BOX PLOT

# %%
w = sns.boxplot(data=data,x = 'Occupation', y = 'Stress Level')

# %%
w = sns.boxplot(data=data,y= 'Occupation', x = 'Stress Level')

# %%
w = sns.boxplot(data=data,x = 'Sleep Duration', y = 'Quality of Sleep')

# %%
w = sns.violinplot(data=data,x = 'Occupation', y = 'Stress Level')

# %%
w = sns.violinplot(data=data,x = 'Heart Rate', y = 'Stress Level')

# %%
w = sns.violinplot(data=data,x = 'Heart Rate', y = 'Daily Steps')

# %%
w = sns.violinplot(data=data,y = 'Heart Rate', x= 'BMI Category')

# %%
w = sns.violinplot(data=data,x= 'Occupation', y= 'Stress Level')

# %%
w = sns.violinplot(data=data,x= 'Sleep Disorder', y= 'Stress Level')

# %%
w = sns.violinplot(data=data,x= 'Sleep Disorder', y= 'Daily Steps')

# %%
w = sns.violinplot(data=data,x= 'Sleep Disorder', y= 'Blood Pressure')

# %%
w = sns.violinplot(data=data,x= 'Sleep Disorder', y= 'Quality of Sleep')

# %%
w = sns.violinplot(data=data,x= 'Sleep Disorder', y= 'Sleep Duration')

# %%
plt.scatter(data.Age,data.Heart Rate)
# Out:
#   Cell In[73], line 1
#     plt.scatter(data.Age,data.Heart Rate)
#                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
plt.scatter(data['Age'],data['Heart Rate'])
plt.xlabel('Age')
plt.ylabel('Heart Rate')
plt.title('Heart Rarte vs Age')
# Out:
# Text(0.5, 1.0, 'Heart Rarte vs Age')

# %%
plt.scatter(data['Physical Activity Level'], data['Age'])
plt.xlabel('Physical Activity Level')
plt.ylabel('Age')
plt.title('Age vs Physical Activity Levele')
# Out:
# Text(0.5, 1.0, 'Age vs Physical Activity Levele')

# %%
# Scatterplots are maped in facetgrig
g = sns.FacetGrid(data,row='Occupation',hue = 'Occupation')
g = g.map(plt.scatter,'Stress Level','Quality of Sleep')

# %%
g = sns.FacetGrid(data,row='Occupation',hue = 'Occupation')
g = g.map(plt.scatter,'Physical Activity Level','Physical Activity Level')

# %%
g = sns.FacetGrid(data,row='Age',hue = 'Age')
g = g.map(plt.scatter,'Physical Activity Level','Physical Activity Level')
